# %%
#Packages
import sys
import numpy 
import matplotlib
import pandas
import sklearn


#importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import  scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix


#loading the dataset
names1=['id','clump_thickness','univorm_cell_size','uniform_cell_shape','marginal_adhesion','single_epithelial_size','bare_nuclei','bland_chromatin','normal_nuceloli','mitoses','class']
dataset=pd.read_csv("data1.csv",names=names1)


parameter=names1[1:]

dataset.head()

#taking care of missing data
dataset.replace('?',-99999,inplace=True)
print(dataset.axes)
dataset.drop(['id'],1,inplace=True)

#shape of dataset
print(dataset.shape)

# do dataset visualization
dataset.describe()

print(dataset.loc[6])

#plot histogram for each variable
dataset.hist(figsize=(10,10))
plt.show()

#create scatter plot matrix
scatter_matrix(dataset,figsize=(18,18))
plt.show()

#spliting into X and Y
X=dataset.iloc[:,:-1]
Y=dataset.iloc[:,9]

#splitting into training and test set
from sklearn.model_selection import train_test_split
X_train ,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

#specifying testing option
seed=8
scoring='accuracy'

#Define model to train
models=[]
models.append(('KNN',KNeighborsClassifier(n_neighbors=5)))
models.append(('SVM',SVC()))
models.append(('LogisticRegression',LogisticRegression()))
models.append(('DecisionTreeClassifier',DecisionTreeClassifier()))
models.append(('GaussianNB',GaussianNB()))

models

results=[]
names=[]
for name,model in models:
    kfold=KFold(n_splits=10,random_state=seed)
    cv_results=cross_val_score(model,X_train,Y_train,cv=kfold,scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg="%s: %f (%f)" %(name,cv_results.mean(),cv_results.std())
    print(msg)

#make predictions on validation dataset
for name,model in models:
    model.fit(X_train,Y_train)
    predictions=model.predict(X_test)
    print(name)
    print(accuracy_score(Y_test,predictions))
    print(classification_report(Y_test,predictions))
    

#now come to prediction at Example using KNN
algo1=KNeighborsClassifier(n_neighbors=5)
algo1.fit(X_train,Y_train)
accuracy1 = algo1.score(X_test, Y_test)
print(accuracy1)


#now come to prediction at Example using SVM
algo2=SVC()
algo2.fit(X_train,Y_train)
accuracy2 = algo2.score(X_test, Y_test)
print(accuracy2)


#now come to prediction at Example using LogisticRegression
algo3=LogisticRegression()
algo3.fit(X_train,Y_train)
accuracy3 = algo3.score(X_test, Y_test)
print(accuracy3)

#now come to prediction at Example using GaussianNB
algo4=GaussianNB()
algo4.fit(X_train,Y_train)
accuracy4 = algo4.score(X_test, Y_test)
print(accuracy4)

#now come to prediction at Example using DecisionTreeClassifier
algo5=DecisionTreeClassifier()
algo5.fit(X_train,Y_train)
accuracy5 = algo5.score(X_test, Y_test)
print(accuracy5)

#prediction on example
# example= np.array([[1,1,1,1,1,9,5,4,1]])
# example = example.reshape(len(example), -1)
# prediction = algo3.predict(example)
# if(prediction==4):
#     print("Breast Cancer is:Malignant")
# if(prediction==2):
#     print("Breast Cancer is:Benign")



# check=[]
# list=[]
# for i in range(9):
#     list.append(int(input("enter {} value = ".format(parameter[i]))))

check.append(datalist)
ar=np.array(check)
ar =ar.reshape(len(example), -1)

prediction = algo1.predict(ar)
if(prediction==4):
    print("Breast Cancer is:Malignant")
if(prediction==2):
    print("Breast Cancer is:Benign")

# %%
prediction = algo2.predict(ar)
if(prediction==4):
    print("Breast Cancer is:Malignant")
if(prediction==2):
    print("Breast Cancer is:Benign")
# Out:
# Breast Cancer is:Malignant

# %%
prediction = algo3.predict(ar)
if(prediction==4):
    print("Breast Cancer is:Malignant")
if(prediction==2):
    print("Breast Cancer is:Benign")
# Out:
# Breast Cancer is:Malignant

# %%
prediction = algo4.predict(ar)
if(prediction==4):
    print("Breast Cancer is:Malignant")
if(prediction==2):
    print("Breast Cancer is:Benign")
# Out:
# Breast Cancer is:Malignant

# %%
prediction = algo5.predict(ar)
if(prediction==4):
    print("Breast Cancer is:Malignant")
if(prediction==2):
    print("Breast Cancer is:Benign")
# Out:
# Breast Cancer is:Malignant

# %%
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

# %%
pd1=algo1.predict(X_test)
acc1=accuracy_score(Y_test,pd1)
print("accuracy of model=",acc1)
error1=mean_squared_error(Y_test,pd1)
print("error =",np.sqrt(error1))
# Out:
# accuracy of model= 0.9809523809523809
# error = 0.2760262237369417

# %%
pd2=algo2.predict(X_test)
acc2=accuracy_score(Y_test,pd1)
print("accuracy of model=",acc2)
error2=mean_squared_error(Y_test,pd2)
print("error =",np.sqrt(error2))
# Out:
# accuracy of model= 0.9809523809523809
# error = 0.4140393356054125

# %%
pd3=algo3.predict(X_test)
acc3=accuracy_score(Y_test,pd1)
print("accuracy of model=",acc3)
error3=mean_squared_error(Y_test,pd3)
print("error =",np.sqrt(error3))
# Out:
# accuracy of model= 0.9809523809523809
# error = 0.3903600291794133

# %%
pd4=algo4.predict(X_test)
acc4=accuracy_score(Y_test,pd1)
print("accuracy of model=",acc4)
error4=mean_squared_error(Y_test,pd4)
print("error =",np.sqrt(error4))
# Out:
# accuracy of model= 0.9809523809523809
# error = 0.4140393356054125

# %%
pd5=algo5.predict(X_test)
acc5=accuracy_score(Y_test,pd1)
print("accuracy of model=",acc5)
error5=mean_squared_error(Y_test,pd5)
print("error =",np.sqrt(error5))
# Out:
# accuracy of model= 0.9809523809523809
# error = 0.4976133515281193

# %%
print("KNN",confusion_matrix(Y_test,pd1))
print("SVM",confusion_matrix(Y_test,pd2))
print("LogisticRegression",confusion_matrix(Y_test,pd3))
print("GaussianNB",confusion_matrix(Y_test,pd4))
print("DecisionTreeClassifier",confusion_matrix(Y_test,pd5))
# Out:
# KNN [[136   3]
#  [  1  70]]
# SVM [[130   9]
#  [  0  71]]
# LogisticRegression [[135   4]
#  [  4  67]]
# GaussianNB [[133   6]
#  [  3  68]]
# DecisionTreeClassifier [[133   6]
#  [  7  64]]

# %%
# Out:
#      clump_thickness  univorm_cell_size  uniform_cell_shape  \
# 403                3                  1                   1
# 284                7                  4                   5
# 615                4                  1                   3
# 256                3                  1                   1
# 296                5                  3                   4
# 309                3                  1                   1
# 132                5                 10                   8
# 120                1                  1                   2
# 679                2                  1                   1
# 524                3                  1                   1
# 333                5                  4                   6
# 74                10                  6                   4
# 514                6                  6                   7
# 357                8                 10                  10
# 681                5                 10                  10
# ...
