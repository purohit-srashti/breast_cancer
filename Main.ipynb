# %%
#Packages
import sys
import numpy 
import matplotlib
import pandas
import sklearn


#importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import  scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from tkinter import *
import tkinter.messagebox


def show():
    datalist=[]
    datalist.append(int(Clump_thickness.get()))
    datalist.append(int(Univorm_cell_size.get()))
    datalist.append(int(Uniform_cell_shape.get()))
    datalist.append(int(Marginal_adhesion.get()))
    datalist.append(int(Single_epithelial_size.get()))
    datalist.append(int(Bare_nuclei.get()))
    datalist.append(int(Bland_chromatin.get()))
    datalist.append(int(Normal_nuceloli.get()))
    datalist.append(int(Mitosis.get()))
    print(datalist)


    #loading the dataset
    names1=['id','clump_thickness','univorm_cell_size','uniform_cell_shape','marginal_adhesion','single_epithelial_size','bare_nuclei','bland_chromatin','normal_nuceloli','mitoses','class']
    dataset=pd.read_csv("data1.csv",names=names1)


    parameter=names1[1:]


    #taking care of missing data
    dataset.replace('?',-99999,inplace=True)
    #print(dataset.axes)
    dataset.drop(['id'],1,inplace=True)




    #spliting into X and Y
    X=dataset.iloc[:,:-1]
    Y=dataset.iloc[:,9]

    #splitting into training and test set
    from sklearn.model_selection import train_test_split
    X_train ,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

    #specifying testing option
    seed=8
    scoring='accuracy'

    #Define model to train
    models=[]
    models.append(('KNN',KNeighborsClassifier(n_neighbors=5)))
    models.append(('SVM',SVC()))
    models.append(('LogisticRegression',LogisticRegression()))
    models.append(('DecisionTreeClassifier',DecisionTreeClassifier()))
    models.append(('GaussianNB',GaussianNB()))


    results=[]
    names=[]
    for name,model in models:
            kfold=KFold(n_splits=10,random_state=seed)
            cv_results=cross_val_score(model,X_train,Y_train,cv=kfold,scoring=scoring)
            results.append(cv_results)
            names.append(name)
            msg="%s: %f (%f)" %(name,cv_results.mean(),cv_results.std())


    #make predictions on validation dataset
    for name,model in models:
            model.fit(X_train,Y_train)
            predictions=model.predict(X_test)



    #now come to prediction at Example using KNN
    algo1=KNeighborsClassifier(n_neighbors=5)
    algo1.fit(X_train,Y_train)
    
    
    #result window
    ans = Tk()
    ans.title("Breast Cancer Analysis")
    df=np.array([datalist])
    prediction=algo1.predict(df);
    text1=""
    if(prediction==4):
        text1="Breast  Cancer  is   MALIGNANT"
         
    if(prediction==2):
        text1="Breast  Cancer  is   BENIGN"
        

    Label(ans).grid(row=0,column=0,padx=98,pady=20)
    Label(ans).grid(row=0,column=1,padx=98)
    Label(ans).grid(row=0,column=2,padx=98)
    Label(ans).grid(row=0,column=3,padx=98)
    
    Label(ans).grid(row=1,column=0,padx=98,pady=20)
    Label(ans,text="Name : ", font = 'Times 20 bold', bg='white', fg='red').grid(row=1,column=1,padx=98)
    Label(ans,text=Name.get(), font = 'Times 15 bold', bg='white').grid(row=1,column=2,padx=98)
    Label(ans).grid(row=1,column=3,padx=98)
    
    
    Label(ans).grid(row=2,column=0,padx=98,pady=20)
    Label(ans,text="Age : ", font = 'Times 20 bold', bg='white', fg='red').grid(row=2,column=1,padx=98)
    Label(ans,text=int(Age.get()), font = 'Times 15 bold', bg='white').grid(row=2,column=2,padx=98)
    Label(ans).grid(row=2,column=3,padx=98)
    
    
    Label(ans).grid(row=3,column=0,padx=98,pady=20)
    Label(ans,text="Contact_No. : ", font = 'Times 20 bold', bg='white', fg='red').grid(row=3,column=1,padx=98)
    Label(ans,text=int(Contact_No.get()), font = 'Times 15 bold', bg='white').grid(row=3,column=2,padx=98)
    Label(ans).grid(row=3,column=3,padx=98)
    
    
    Label(ans).grid(row=4,column=0,padx=98,pady=20)
    Label(ans,text="Disease :", font = 'Times 20 bold', bg='white', fg='red').grid(row=4,column=1,padx=98)
    Label(ans,text=text1, font = 'Times 15 bold', bg='white').grid(row=4,column=2,padx=98)
    Label(ans).grid(row=4,column=3,padx=98)
    
    Label(ans).grid(row=5,column=0,padx=98,pady=20)
    Label(ans).grid(row=5,column=1,padx=98)
    Label(ans).grid(row=5,column=2,padx=98)
    Label(ans).grid(row=5,column=3,padx=98)
    
    
    
    
    ans.mainloop()
    
    
    
    
#input window 
tk = Tk ()
tk.title("Breast Cancer Analysis")
p1 = StringVar()
p2 = StringVar()
p3 = StringVar()
p4 = StringVar()
p5 = StringVar()
p6 = StringVar()
p7 = StringVar()
p8 = StringVar()
p9 = StringVar()
p10 = StringVar()
p11 = StringVar()
p12 = StringVar()


Label(tk).grid(row=0,column=0,padx=98,pady=20)
Label(tk).grid(row=0,column=1,padx=98)
Label(tk).grid(row=0,column=2,padx=98)
Label(tk).grid(row=0,column=3,padx=98)
Label(tk).grid(row=0,column=4,padx=98)
Label(tk).grid(row=0,column=5,padx=98)
Label(tk).grid(row=0,column=6,padx=98)


label = Label ( tk, text="Name:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=1, column=0,sticky=W,ipadx=80,ipady=0)
Name = Entry(tk, textvariable=p1, bd=5)
Name.grid(row=1, column=1, sticky=W,ipadx=10)

label = Label ( tk, text="Age:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=1, column=2,sticky=W,ipadx=10)
Age = Entry(tk, textvariable=p2, bd=5)
Age.grid(row=1, column=3, sticky=W,ipadx=10)

label = Label ( tk, text="Contact_No.:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=1, column=4,sticky=W,ipadx=10)
Contact_No = Entry(tk, textvariable=p3, bd=5)
Contact_No.grid(row=1, column=5, sticky=W,ipadx=10)





Label(tk).grid(row=2,column=0,padx=98,pady=20)
Label(tk).grid(row=2,column=1,padx=98)
Label(tk).grid(row=2,column=2,padx=98)
Label(tk).grid(row=2,column=3,padx=98)
Label(tk).grid(row=2,column=4,padx=98)
Label(tk).grid(row=2,column=5,padx=98)
Label(tk).grid(row=2,column=6,padx=98)


label = Label ( tk, text="Clump_thickness:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=3, column=0,sticky=W,ipadx=80,ipady=0)
Clump_thickness = Entry(tk, textvariable=p4, bd=5)
Clump_thickness.grid(row=3, column=1, sticky=W,ipadx=10)

label = Label ( tk, text="Univorm_cell_size:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=3, column=2,sticky=W,ipadx=10)
Univorm_cell_size = Entry(tk, textvariable=p5, bd=5)
Univorm_cell_size.grid(row=3, column=3, sticky=W,ipadx=10)

label = Label ( tk, text="Uniform_cell_shape:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=3, column=4,sticky=W,ipadx=10)
Uniform_cell_shape = Entry(tk, textvariable=p6, bd=5)
Uniform_cell_shape.grid(row=3, column=5, sticky=W,ipadx=10)




Label(tk).grid(row=4,column=0,padx=98,pady=20)
Label(tk).grid(row=4,column=1,padx=98)
Label(tk).grid(row=4,column=2,padx=98)
Label(tk).grid(row=4,column=3,padx=98)
Label(tk).grid(row=4,column=4,padx=98)
Label(tk).grid(row=4,column=5,padx=98)
Label(tk).grid(row=4,column=6,padx=98)


label = Label ( tk, text="Marginal_adhesion:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=5, column=0,sticky=W,ipadx=80,ipady=0)
Marginal_adhesion = Entry(tk, textvariable=p7, bd=5)
Marginal_adhesion.grid(row=5, column=1, sticky=W,ipadx=10)

label = Label ( tk, text="Single_epithelial_size:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=5, column=2,sticky=W,ipadx=10)
Single_epithelial_size = Entry(tk, textvariable=p8, bd=5)
Single_epithelial_size.grid(row=5, column=3, sticky=W,ipadx=10)

label = Label ( tk, text="Bare_nuclei:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=5, column=4,sticky=W,ipadx=10)
Bare_nuclei = Entry(tk, textvariable=p9, bd=5)
Bare_nuclei.grid(row=5, column=5, sticky=W,ipadx=10)




Label(tk).grid(row=6,column=0,padx=98,pady=20)
Label(tk).grid(row=6,column=1,padx=98)
Label(tk).grid(row=6,column=2,padx=98)
Label(tk).grid(row=6,column=3,padx=98)
Label(tk).grid(row=6,column=4,padx=98)
Label(tk).grid(row=6,column=5,padx=98)
Label(tk).grid(row=6,column=6,padx=98)


label = Label ( tk, text="Bland_chromatin:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=7, column=0,sticky=W,ipadx=80,ipady=0)
Bland_chromatin = Entry(tk, textvariable=p10, bd=5)
Bland_chromatin.grid(row=7, column=1, sticky=W,ipadx=10)

label = Label ( tk, text="Normal_nuceloli:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=7, column=2,sticky=W,ipadx=10)
Normal_nuceloli = Entry(tk, textvariable=p11, bd=5)
Normal_nuceloli.grid(row=7, column=3, sticky=W,ipadx=10)

label = Label ( tk, text="Mitosis:", font = 'Times 15 bold', bg='white', fg='red', height =1, width=0)
label.grid(row=7, column=4,sticky=W,ipadx=10)
Mitosis = Entry(tk, textvariable=p12, bd=5)
Mitosis.grid(row=7, column=5, sticky=W,ipadx=10)



Label(tk).grid(row=8,column=0,padx=98,pady=20)
Label(tk).grid(row=8,column=1,padx=98)
Label(tk).grid(row=8,column=2,padx=98)
Label(tk).grid(row=8,column=3,padx=98)
Label(tk).grid(row=8,column=4,padx=98)
Label(tk).grid(row=8,column=5,padx=98)
Label(tk).grid(row=8,column=6,padx=98)
Button(tk,text="Result", font = 'Times 15 bold', command=show).grid(row=9,column=4)

Label(tk).grid(row=10,column=0,padx=98,pady=20)
Label(tk).grid(row=10,column=1,padx=98)
Label(tk).grid(row=10,column=2,padx=98)
Label(tk).grid(row=10,column=3,padx=98)
Label(tk).grid(row=10,column=4,padx=98)
Label(tk).grid(row=10,column=5,padx=98)
Label(tk).grid(row=10,column=6,padx=98)



tk.mainloop()
# Out:
# [44, 5, 5, 5, 5, 5, 5, 5, 5]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %% [markdown]
# #
