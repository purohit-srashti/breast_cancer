# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
data=pd.read_csv('cancer.csv')

# %%
data.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           1        17.99         10.38          122.80     1001.0
# 842517           1        20.57         17.77          132.90     1326.0
# 84300903         1        19.69         21.25          130.00     1203.0
# 84348301         1        11.42         20.38           77.58      386.1
# 84358402         1        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean           ...             \
# id                                                     ...
# ...

# %%
data['diagnosis'] = data['diagnosis'].apply(lambda x: '1' if x == 'M' else '0')
data = data.set_index('id')
del data['Unnamed: 32']

# %%
data.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           1        17.99         10.38          122.80     1001.0
# 842517           1        20.57         17.77          132.90     1326.0
# 84300903         1        19.69         21.25          130.00     1203.0
# 84348301         1        11.42         20.38           77.58      386.1
# 84358402         1        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean           ...             \
# id                                                     ...
# ...

# %%
print(data.groupby('diagnosis').size())
# Out:
# diagnosis
# 0    357
# 1    212
# dtype: int64

# %%
Y = data['diagnosis'].values
X = data.drop('diagnosis', axis=1).values

X_train1, X_test1, Y_train1, Y_test1 = train_test_split (X, Y, test_size = 0.30, random_state=21)

# %%
Y1= data['diagnosis'].values
X1= data.drop('diagnosis', axis=1).values

X_train2, X_test2, Y_train2, Y_test2 = train_test_split (X1, Y1, test_size = 0.70, random_state=21)

# %%
a=X1[300:]

# %%
x_train3=X1[::]
y_train3=Y1[::]
x_test3=X1[250:]
y_test3=Y1[250:]

# %%
print(x_train3.size/30)
print(y_train3.size)
print(x_test3.size/30)
print(y_test3.size)
# Out:
# 569.0
# 569
# 100.0
# 100

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
trainer1=LogisticRegression()

learner1=trainer1.fit(X_train1,Y_train1)

pd1=learner1.predict(X_test1)

acc1=accuracy_score(Y_test1,pd1)
print("accuracy of model=",acc1)

error1=mean_squared_error(Y_test1,pd1)

print("error =",np.sqrt(error1))

plt.plot(X_test1,Y_test1,'go-')
plt.plot(X_test1,pd1,'r*')
plt.xlabel("X_input")
plt.ylabel("Predicted_SVC")
plt.legend({"ya","yp"})
plt.show()
# Out:
# accuracy of model= 0.9473684210526315
# error = 0.22941573387056177

# %%
trainer2=LogisticRegression()

learner2=trainer2.fit(X_train2,Y_train2)

pd2=learner2.predict(X_test2)

acc2=accuracy_score(Y_test2,pd2)
print("accuracy of model=",acc2)

error2=mean_squared_error(Y_test2,pd2)

print("error =",np.sqrt(error2))

plt.plot(X_test2,Y_test2,'go-')
plt.plot(X_test2,pd2,'r*')
plt.xlabel("X_input")
plt.ylabel("Predicted_SVC")
plt.legend({"ya","yp"})
plt.show()
# Out:
# accuracy of model= 0.9223057644110275
# error = 0.27873685724886194

# %%
trainer3=LogisticRegression()

learner3=trainer3.fit(x_train3,y_train3)

pd3=learner3.predict(x_test3)

acc3=accuracy_score(y_test3,pd3)
print("accuracy of model=",acc3)

error3=mean_squared_error(y_test3,pd3)

print("error =",np.sqrt(error3))

plt.plot(y_test3,y_test3,'go')
plt.plot(y_test3,pd3,'r*')
plt.xlabel("X_input")
plt.ylabel("Predicted_SVC")
plt.legend({"ya","yp"})
plt.show()
# Out:
# accuracy of model= 0.9686520376175548
# error = 0.17705355794912775

# %%
trainer3=LogisticRegression()

learner3=trainer3.fit(x_train3,y_train3)

pd3=learner3.predict(x_test3)

acc3=accuracy_score(y_test3,pd3)
print("accuracy of model=",acc3)

error3=mean_squared_error(y_test3,pd3)

print("error =",np.sqrt(error3))

plt.plot(y_test3,y_test3,'go')
plt.plot(y_test3,pd3,'r*')
plt.xlabel("X_input")
plt.ylabel("Predicted_SVC")
plt.legend({"ya","yp"})
plt.show()
# Out:
# accuracy of model= 0.9495798319327731
# error = 0.22454435656953592

# %%
trainer3=LogisticRegression()

learner3=trainer3.fit(x_train3,y_train3)

pd3=learner3.predict(x_test3)

acc3=accuracy_score(y_test3,pd3)
print("accuracy of model=",acc3)

error3=mean_squared_error(y_test3,pd3)

print("error =",np.sqrt(error3))

plt.plot(y_test3,y_test3,'go')
plt.plot(y_test3,pd3,'r*')
plt.xlabel("X_input")
plt.ylabel("Predicted_SVC")
plt.legend({"ya","yp"})
plt.show()
# Out:
# accuracy of model= 0.92
# error = 0.282842712474619

# %%
trainer3=LogisticRegression()

learner3=trainer3.fit(x_train3,y_train3)

pd3=learner3.predict(x_test3)

acc3=accuracy_score(y_test3,pd3)
print("accuracy of model=",acc3)

error3=mean_squared_error(y_test3,pd3)

print("error =",np.sqrt(error3))

plt.plot(y_test3,y_test3,'go')
plt.plot(y_test3,pd3,'r*')
plt.xlabel("X_input")
plt.ylabel("Predicted_SVC")
plt.legend({"ya","yp"})
plt.show()
# Out:
# accuracy of model= 0.9686520376175548
# error = 0.17705355794912775
